# %%
#pip install bsedata

# %%
#imports
from bsedata.bse import BSE
import pandas as pd

# %%
bse = BSE()
print(bse)
# Out:
# Driver Class for Bombay Stock Exchange (BSE)

# %%
# to execute "updateScripCodes" on instantiation
bse = BSE(update_codes = True)

# %%
#stock details based on security id
quote = bse.getQuote('534976')
print(quote)
# Out:
# {'companyName': 'V-MART RETAIL LTD.', 'currentValue': '2750.55', 'change': '-28.70', 'pChange': '-1.03', 'updatedOn': '04 Jun 21 | 04:00 PM', 'priceBand': '', 'securityID': 'VMART', 'scripCode': '534976', 'group': 'A  / S&P BSE 500', 'faceValue': '10.00', 'industry': 'Department Stores', 'previousClose': '2779.25', 'previousOpen': '2800.00', 'dayHigh': '2800.00', 'dayLow': '2746.00', '52weekHigh': '3129.40', '52weekLow': '1662.15', 'weightedAvgPrice': '2771.48', 'totalTradedValue': '0.23 Cr.', 'totalTradedQuantity': '0.01 Lakh', '2WeekAvgQuantity': '0.01 Lakh', 'marketCapFull': '5,420.27 Cr.', 'marketCapFreeFloat': '2,493.33 Cr.', 'upperPriceBand': '', 'lowerPriceBand': '', 'buy': {'1': {'quantity': '-', 'price': '0.00'}, '2': {'quantity': '-', 'price': '0.00'}, '3': {'quantity': '-', 'price': '0.00'}, '4': {'quantity': '-', 'price': '0.00'}, '5': {'quantity': '-', 'price': '0.00'}}, 'sell': {'1': {'price': '0.00', 'quantity': '-'}, '2': {'price': '0.00', 'quantity': '-'}, '3': {'pri
# ...

# %%
#multiple stock 
quotelist = ["540064", "507880"]
for code in quotelist:
    quote = bse.getQuote(code)
    print(quote["companyName"])
    print(quote["currentValue"])
    print(quote["updatedOn"])
# Out:
# Future Retail Ltd
# 55.05
# 04 Jun 21 | 04:00 PM
# V.I.P.INDUSTRIES LTD.-$
# 390.10
# 04 Jun 21 | 04:00 PM

# %%
#top gainers
topGainers = b.topGainers()
data=pd.DataFrame(topGainers, columns=['securityID','scripCode','LTP','change','pChange'])
data
# Out:
#    securityID scripCode     LTP change pChange
# 0    RELIGARE    532915  142.35  23.70   19.97
# 1   KIRIINDUS    532967  594.40  78.95   15.32
# 2  IBULHSGFIN    535789  261.40  32.60   14.25
# 3    MAHABANK    532525   29.00   3.25   12.62
# 4     APTECHT    532475  236.10  25.10   11.90

# %%
#top losers
topLosers = b.topLosers()
data=pd.DataFrame(topLosers, columns=['securityID','scripCode','LTP','change','pChange'])
data
# Out:
#    securityID scripCode       LTP   change pChange
# 0  VSTTILLERS    531266  2,131.80  -133.00   -5.87
# 1    NILKAMAL    523385  2,343.30  -145.05   -5.83
# 2     NUCLEUS    531209    580.25   -22.65   -3.76
# 3         SIS    540673    426.80   -16.25   -3.67
# 4  SUNCLAYLTD    520056  3,594.30  -132.70   -3.56

# %%
#get all security codes
for i,j in bse.getScripCodes().items():
    print(i+" : "+j)
# Out:
# 533022 : 20 Microns Ltd.
# 532628 : 3i Infotech Ltd.
# 523395 : 3m India Ltd.
# 590116 : 7seas Technologies Ltd-$
# 512161 : 8k Miles Software Services Ltd.
# 538351 : A.f. Enterprises Ltd
# 539300 : A.k. Spintex Ltd
# 530499 : A.k.capital Services Ltd.
# 533292 : A2z Infra Engineering Limited
# 531611 : Aadhaar Ventures India Ltd.
# 530027 : Aadi Industries Ltd.
# 531866 : Aagam Capital Ltd.
# 539096 : Aananda Lakshmi Spinning Mills Ltd
# 538812 : Aanchal Ispat Ltd
# 524412 : Aarey Drugs & Pharmaceuticals Ltd.
# 524348 : Aarti Drugs Ltd.
# 524208 : Aarti Industries Ltd.
# 514274 : Aarvee Denims & Exports Ltd.
# 531731 : Aarya Global Shares And Securities Ltd.
# 519319 : Aashee Infotech Ltd.
# 512038 : Aaswa Trading & Exports Ltd.
# 523204 : Aban Offshore Ltd.
# 512165 : Abans Enterprises Ltd
# 500002 : Abb India Limited
# 500488 : Abbott India Ltd.
# 505665 : Abc Bearings Ltd.-$
# 513119 : Abc Gas (international) Ltd.
# 520123 : Abc India Ltd.-$
# 532682 : Abg Shipyard Ltd.
# ...

# %%
#getting period trend data
periodTrend = bse.getPeriodTrend('540064','12M')
data=pd.DataFrame(periodTrend, columns=['date','value', 'vol'])
data
# Out:
#                          date   value      vol
# 0    Thu Jun 04 2020 00:00:00   96.30   415600
# 1    Fri Jun 05 2020 00:00:00  101.10   113559
# 2    Mon Jun 08 2020 00:00:00  103.30   557992
# 3    Tue Jun 09 2020 00:00:00   99.70   180697
# 4    Wed Jun 10 2020 00:00:00  104.50   503219
# ..                        ...     ...      ...
# 247  Mon May 31 2021 00:00:00   47.70   250836
# 248  Tue Jun 01 2021 00:00:00   47.75   377486
# 249  Wed Jun 02 2021 00:00:00   50.00  1426425
# 250  Thu Jun 03 2021 00:00:00   52.50   684699
# 251  Fri Jun 04 2021 00:00:00   55.05  1795150
#
# [252 rows x 3 columns]
